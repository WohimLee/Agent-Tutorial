# %% [markdown]
# ![image.png](attachment:fc4eac23-f371-4645-adb3-57a3d121e6f4.png)

# %% [markdown]
# ![image.png](attachment:3b64beb7-25a5-4378-a017-f774b409fb76.png)

# %% [markdown]
# # 1. 什么是MCP，为什么出现了MCP？

# %% [markdown]
# ![image.png](attachment:a71c0a4c-d148-4254-968d-2e13a86bdfcf.png)

# %% [markdown]
# ![image.png](attachment:4064ebe9-6ab0-4b9c-b511-334b51ba57e4.png)

# %% [markdown]
# ![image.png](attachment:26e05c97-84d1-4d87-b333-c7d300898316.png)

# %% [markdown]
# ![image.png](attachment:f511d86a-40fc-4153-884b-1fbc0cc55a8d.png)

# %% [markdown]
# ![image.png](attachment:ce69a3fd-e9e8-4a55-8a4b-ca80f0804b40.png)

# %% [markdown]
# ![image.png](attachment:9f63b4e6-cb17-4b45-bc75-c5f1fdb3683f.png)

# %% [markdown]
# # 2. 如何快速用起来MCP

# %% [markdown]
# ## 2.1 理解Client和Host连接的方式

# %% [markdown]
# ![image.png](attachment:ca1aa33f-5306-439b-b40c-efe8f419a69f.png)

# %% [markdown]
# ![image.png](attachment:fe8a3ba3-4b9d-48d9-b014-878db1600aea.png)

# %% [markdown]
# ## 2.2 如何用网络上的MCP服务

# %% [markdown]
# ### 首先我们要找一个Client，既能帮你连接各地的MCP服务，又能帮你连接LLM

# %% [markdown]
# | 名称                                    | 类型               | 是否开源                                                        | 支持特点                                | 说明                                           |
# | ------------------------------------- | ---------------- | ----------------------------------------------------------- | ----------------------------------- | -------------------------------------------- |
# | **Claude Desktop**                    | 桌面应用             | ❌                                                           | ✅ Claude + MCP 工具调度                 | Anthropic 官方或社区构建的 Claude 桌面集成环境，支持调用 MCP 工具 |
# | **Cline**                             | 浏览器插件 / Agent 面板 | ✅ [GitHub](https://github.com/cline-ai/cline)               | ✅ ChatGPT & Claude 集成 ✅ MCP tool 调用 | 适用于浏览器场景，工具栏式 Agent Client                   |
# | **Cherry Studio**                     | 桌面端集成开发环境        | ✅ [GitHub](https://github.com/cherrystudio-ai/cherrystudio) | ✅ 支持 Claude、GPT、工具调用                | 轻量级 IDE 风格，集成 LLM 与 Tool 使用                  |
# | **SkyPilot Agent Desktop**            | 桌面工具             | 部分开源                                                        | ✅ 工具调用 + 模型控制                       | SkyPilot 扩展的 Agent 桌面端项目，支持插件扩展              |
# | **StarAgent**                         | Web 平台           | ✅                                                           | ✅ MCP工具调用 ✅角色配置                     | 以角色为中心的 Agent 平台，社区开发                        |
# | **Reverie Agent（原 OpenAgents）**       | Web App / CLI    | ✅                                                           | ✅ Tool use ✅ 多 Agent 协同             | 比较适合开发者测试，支持 tool chaining                   |
# | **Ollama + MCP UI 客户端（如 Visual LLM）** | 桌面 / 网页          | ✅                                                           | ✅ 本地模型 + 工具                         | 基于 Ollama 的本地模型 Agent 支持工具链                  |

# %% [markdown]
# ### 接着我们要找提供mcp server的平台

# %% [markdown]
# - http://mcp.so/
# - https://mcpmarket.com/zh
# - https://github.com/modelcontextprotocol/servers

# %% [markdown]
# - 直接注册
# - 商店安装
# - 用别人写好了开源的MCP

# %% [markdown]
# #### 高德地图
# http://mcp.so/server/amap-maps/amap?tab=tools

# %% [markdown]
# #### Fetch网页内容获取
# ![image.png](attachment:8f672abb-462a-44c0-bc57-49f316aa5570.png)

# %% [markdown]
# #### 小红书MCP
# https://glama.ai/mcp/servers/%40chenningling/RedBook-Search-Comment-MCP?utm_source=chatgpt.com

# %% [markdown]
# ## 2.3 如何自己写一个MCP服务

# %% [markdown]
# ### 先回顾一下

# %% [markdown]
# ![image.png](attachment:58c2c9c4-bf0a-41b1-9de4-a263bbb7660f.png)

# %% [markdown]
# ![image.png](attachment:ff840e5c-0754-4c62-ab34-716074a1c38a.png)

# %% [markdown]
# ![image.png](attachment:f4083953-22f2-4276-9264-e1d992f2ed5d.png)

# %% [markdown]
# ![image.png](attachment:96371de8-2321-4a68-baf9-760466ec20bb.png)

# %% [markdown]
# ![image.png](attachment:d61fae7f-299a-4a00-9f58-a9cd30a9d90f.png)

# %% [markdown]
# ![image.png](attachment:044fa9b9-1acb-4eaf-9b84-652b852d04c7.png)

# %% [markdown]
# # 3/4 核心机制+完整MCP流程

# %%
#见代码

# %% [markdown]
# # 5 展望

# %% [markdown]
# ![image.png](attachment:2e8fd520-35a7-4fa2-8cfb-4e7bf0d9ebeb.png)
